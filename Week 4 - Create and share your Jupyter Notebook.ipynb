# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ###### Bhuvaneswari Raghuraman
# Data Science Evangelist

# %% [markdown]
# *I am interested in data science because it guides operations and decisions by using actual data,thereby preserving the truth from being distorted by emotions and personal agenda. As it is results oriented, all the hours of work put into a given assignment always shows an output which makes the entire process enjoyable and well worth the effort.

# %% [markdown]
# ### The following cell calculates the product of two variables and prints the result

# %%
a = 3
b = 4
product = 3 * 4
print(product)
# Out:
# 12

# %% [markdown]
# ***
#
# **What Stoicism teaches us**
#
# ***
#
# Stoicism is a branch of philosophy that teaches us to be more resilient, happier, more virtuous and wise - making us better people, parents, friends and professionals
#
# The following are the four virtues of Stoicism
# * Courage
# * Temperance
# * Justice
# * Wisdom
#
# The most notable quote of the stoics is "Memento Mori" - meaning 'remember your mortality'
#
# One can find out more about Stoicism from a casual search in Google. However one of the good sources on this is <a href="https://plato.stanford.edu/entries/stoicism/" target="_blank" > Stanford's Encyclopedia of Philosophy </a>
#
# ![The Stoics](https://373819-1169963-raikfcquaxqncofqfm.stackpathdns.com/wp-content/uploads/2016/07/marcus.jpg)
